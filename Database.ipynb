# %%
import pandas as pd 
import math
import matplotlib.pyplot as plt 
import statsmodels
import gdown
import seaborn as sns

# %%
file_id= "1N8Bn-RDz7K_XsMzXIqMfGGUqw9ObQ_0R"
url= f"https://drive.google.com/uc?id={file_id}"
df12_24=pd.read_csv(url)
df12_24.head()
# Out:
#    Unnamed: 0  blockNumber  timestamp_hours  \
# 0           0     21525889           482135
# 1           1     21525886           482135
# 2           2     21525885           482135
# 3           3     21525872           482135
# 4           4     21525849           482135
#
#                                                   id  inputTokenPriceUSD  \
# 0  0x4d5f47fa6a74757f35c14fd3a6ef8e3c9bc514e8575b...         3334.691723
# 1  0x23878914efe38d27c4d67ab83ed1b93a74d4086a575b...            0.998660
# 2  0x32a6268f9ba3642dda7892add74f1d34469a4259575b...            0.999871
# 3  0xcc9ee9483f662091a1de4795249e24ac0ac2630f575b...         3750.980709
# 4  0x018008bfb33d285247a21d44e50697654f754e63575b...            0.999921
#
#    outputTokenPriceUSD  snapshot_timestamp     reserve_name protocol_name  \
# 0                  NaN          1735689587    Wrapped Ether       Aave v3
# 1                  NaN          1735689551       Tether USD       Aave v3
# ...

# %%
file_id="1BQx3WQ6og3HL9UuY_1b5dduvt4d2SP2p"
url=f"https://drive.google.com/uc?id={file_id}"
df11_24=pd.read_csv(url)

# %%
file_id="1DX2wWtRmYXwImIfl6RBNG_TQHnephAbY"
url=f"https://drive.google.com/uc?id={file_id}"
df10_24=pd.read_csv(url)

# %%
file_id="1H4FBH2OMllK0SjbZZzfocxrrFCDWFrE-"
url=f"https://drive.google.com/uc?id={file_id}"
df9_24=pd.read_csv(url)

# %%
file_id="1SMsJ9udwM-XXXVTBJWo-LwVeNSKZg6Qt"
url=f"https://drive.google.com/uc?id={file_id}"
df8_24=pd.read_csv(url)

# %%
file_id="1K7Z6uthFecfgGOBxdeurJfWpIcymNebW"
url=f"https://drive.google.com/uc?id={file_id}"
df7_24=pd.read_csv(url)

# %%
file_id="18MNNfboSW6LyQSQDQXz-e3uyM5yhPlSr"
url=f"https://drive.google.com/uc?id={file_id}"
df6_24=pd.read_csv(url)

# %%
file_id="19pFEG0VXLpOixm0_H6Ynp4Ulky24t6yj"
url=f"https://drive.google.com/uc?id={file_id}"
df5_24=pd.read_csv(url)

# %%
file_id="1_L-zygytaazUK1PYWqXSxGYkZIkwtB6U"
url=f"https://drive.google.com/uc?id={file_id}"
df4_24=pd.read_csv(url)

# %%
file_id="1_sMq3YIAezGPOO8bAZmVfoZ8SLcF84uW"
url=f"https://drive.google.com/uc?id={file_id}"
df3_24=pd.read_csv(url)

# %%
file_id="187_fUMWCgkpNBdexwoBP8b_Lx-MvkwmH"
url=f"https://drive.google.com/uc?id={file_id}"
df2_24=pd.read_csv(url)

file_id="1QoUK2fRZ0ojvrEGwrwte134_0h58ig0F"
url=f"https://drive.google.com/uc?id={file_id}"
df1_24=pd.read_csv(url)

file_id="1Y0aaMeH93QBv4gOTIKc4MrtPmGap8js9"
url=f"https://drive.google.com/uc?id={file_id}"
df12_23=pd.read_csv(url)

file_id="1oxvZbsMkGaF9Ho25nvBVICtLbgNJwzAO"
url=f"https://drive.google.com/uc?id={file_id}"
df11_23=pd.read_csv(url)

file_id="1PTQACE9ffF-rtvSUpVYmJfnDz_c2c_qJ"
url=f"https://drive.google.com/uc?id={file_id}"
df10_23=pd.read_csv(url)

file_id="1WXxyZwT8TZQElCnOo_h2Ldb6qcXtDsOL"
url=f"https://drive.google.com/uc?id={file_id}"
df9_23=pd.read_csv(url)


file_id="1KUqJNKOUMNDvZcM7SVAcPyKLWdrE548D"
url=f"https://drive.google.com/uc?id={file_id}"
df8_23=pd.read_csv(url)

file_id="14Hw0fpdy0aL87pM1ubaYw56iZNub--rj"
url=f"https://drive.google.com/uc?id={file_id}"
df7_23=pd.read_csv(url)

file_id="1W9vgmYIKlXIaVyyb99c1VfV6f3fE1e1F"
url=f"https://drive.google.com/uc?id={file_id}"
df6_23=pd.read_csv(url)

file_id="1Eh0FW7nYCz71zk_A97y3NVK93yQoyHRg"
url=f"https://drive.google.com/uc?id={file_id}"
df5_23=pd.read_csv(url)

file_id="1sBzpgigujrltIPR7WaoUZOK0JOpD1wHF"
url=f"https://drive.google.com/uc?id={file_id}"
df4_23=pd.read_csv(url)

file_id="1XQb5Bd8y_iT0mEJQDLpa7zjrH1Pa-odU"
url=f"https://drive.google.com/uc?id={file_id}"
df3_23=pd.read_csv(url)

file_id="1Qz25tT5fU-h-xUQZYs8xdyPE6ikYxlyf"
url=f"https://drive.google.com/uc?id={file_id}"
df2_23=pd.read_csv(url)

file_id="1ZGaC8Dl9phTyMZgCPlOlvxcxxvJ1Cvxs"
url=f"https://drive.google.com/uc?id={file_id}"
df1_23=pd.read_csv(url)

# %%
concatenated_df = pd.concat([df1_24, df2_24], axis=0, ignore_index=True)
for i in range(3,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_24"]], axis=0, ignore_index=True)
    concatenated_df=df
for i in range(1,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_23"]], axis=0, ignore_index=True)
    concatenated_df=df

# %%
pd.DataFrame(df)
# Out:
#         Unnamed: 0  blockNumber  timestamp_hours  \
# 0                0     19129888           474095
# 1                1     19129888           474095
# 2                2     19129888           474095
# 3                3     19129857           474095
# 4                4     19129834           474095
# ...            ...          ...              ...
# 145084        6069     18688018           472608
# 145085        6070     18687995           472608
# 145086        6071     18687970           472608
# 145087        6072     18687901           472608
# 145088        6073     18687900           472608
#
#                                                        id  inputTokenPriceUSD  \
# 0       0x98c23e9d8f34fefb1b7bd6a91b7ff122f4e16f5cef3b...            1.000092
# 1       0x4d5f47fa6a74757f35c14fd3a6ef8e3c9bc514e8ef3b...         2283.141300
# 2       0x23878914efe38d27c4d67ab83ed1b93a74d4086aef3b...            0.999334
# ...

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df=df.sort_values(by='datetime')
pd.DataFrame(df)
# Out:
#        Unnamed: 0  blockNumber  timestamp_hours  \
# 91594         454     16496806           465223
# 91595         455     16496802           465223
# 91592         452     16496810           465223
# 91593         453     16496808           465223
# 91597         457     16496795           465223
# ...           ...          ...              ...
# 80913          14     21525642           482135
# 80914          15     21525608           482135
# 80899           0     21525889           482135
# 80908           9     21525804           482135
# 80900           1     21525886           482135
#
#                                                       id  inputTokenPriceUSD  \
# 91594  0x018008bfb33d285247a21d44e50697654f754e634719...            0.000000
# 91595  0x98c23e9d8f34fefb1b7bd6a91b7ff122f4e16f5c4719...            0.000000
# 91592  0xa700b4eb416be35b2911fd5dee80678ff64ff6c94719...            0.000000
# ...

# %%
df.to_pickle("hourly.pkl")  # Sauvegarde rapide

# %%
file_id="1Uu8ON3YPTFB2QTnTL1peogZeHs74tFWk"
url=f"https://drive.google.com/uc?id={file_id}"
df12_24=pd.read_csv(url)

file_id="14fAgB1mALLOR0qaYHcEK_-mRzfN2AdIk"
url=f"https://drive.google.com/uc?id={file_id}"
df11_24=pd.read_csv(url)

file_id="1RVkKyUPDpfvlZr-R0VJVyxV9uyFXqFBp"
url=f"https://drive.google.com/uc?id={file_id}"
df10_24=pd.read_csv(url)

file_id="1-ZTFD8hxepYqEYsIElVxQfiCphcFLtzo"
url=f"https://drive.google.com/uc?id={file_id}"
df9_24=pd.read_csv(url)

ValueError
file_id="10PnQSkRg5BI1k8n1SLksDPYDfAMYHLNy"
url=f"https://drive.google.com/uc?id={file_id}"
df8_24=pd.read_csv(url)

file_id="1_1galbHrsqbDApTWiI6D0S0XS8G2_WX6"
url=f"https://drive.google.com/uc?id={file_id}"
df7_24=pd.read_csv(url)

file_id="1d7Qgb5HbSTMxtkmHgZoDPqYpL9Y0ZS_y"
url=f"https://drive.google.com/uc?id={file_id}"
df6_24=pd.read_csv(url)

file_id="1ubRue0C0zsZ8vc3ZU6-kwrs4Neg7EfLq"
url=f"https://drive.google.com/uc?id={file_id}"
df5_24=pd.read_csv(url)

file_id="1MRrrOOrfUeqZteLUGsHY-pZAmxDzGmGI"
url=f"https://drive.google.com/uc?id={file_id}"
df4_24=pd.read_csv(url)

file_id="1kVD6SfJcnAJRZFjy1bP0EdpMZNY57rp7"
url=f"https://drive.google.com/uc?id={file_id}"
df3_24=pd.read_csv(url)

file_id="1qbjOied2PnpsVApT3v6ZLfkQxI80p7rT"
url=f"https://drive.google.com/uc?id={file_id}"
df2_24=pd.read_csv(url)

file_id="1VK3AWppLvEUK-8TCErVZRPeGBbimO2S1"
url=f"https://drive.google.com/uc?id={file_id}"
df1_24=pd.read_csv(url)

file_id="1kq19zZnflhE18R-bJtke9da3rIY76k3r"
url=f"https://drive.google.com/uc?id={file_id}"
df12_23=pd.read_csv(url)

file_id="1MzKd6TpXDdyBMS36gu1ZEBwLLmMXjlJX"
url=f"https://drive.google.com/uc?id={file_id}"
df11_23=pd.read_csv(url)

file_id="1AWbnnNeO0faEDnQjpfih4Q_NTJcCrj6Q"
url=f"https://drive.google.com/uc?id={file_id}"
df10_23=pd.read_csv(url)

file_id="1Q1P380mhlH-pSZWkT9VkXmyyKi-AZ9M1"
url=f"https://drive.google.com/uc?id={file_id}"
df9_23=pd.read_csv(url)

ValueError
file_id="1HaZkZpW5tHq0hDWhlfQP8xwrRTfzK0dr"
url=f"https://drive.google.com/uc?id={file_id}"
df8_23=pd.read_csv(url)

file_id="11X1lGsHGv0i2_Kgjewt9r360v_ZVpTHg"
url=f"https://drive.google.com/uc?id={file_id}"
df7_23=pd.read_csv(url)

file_id="18eb7lFtOC3XsNLM4GY1xCdONERAsKbNL"
url=f"https://drive.google.com/uc?id={file_id}"
df6_23=pd.read_csv(url)

file_id="1qDeCo73rt0lFcJHuADTHWDQZtkJBcHaH"
url=f"https://drive.google.com/uc?id={file_id}"
df5_23=pd.read_csv(url)

file_id="1f6Enu1Yzi86iHi7DE-0K3CC4TRQuBXOb"
url=f"https://drive.google.com/uc?id={file_id}"
df4_23=pd.read_csv(url)

file_id="1Z6wC2BsEK2EYZEhN1kFdF0vM-GLoN_Yd"
url=f"https://drive.google.com/uc?id={file_id}"
df3_23=pd.read_csv(url)

file_id="1qI9YufLV_ESuJeFgAyiYgZ2uXI-8_ouq"
url=f"https://drive.google.com/uc?id={file_id}"
df2_23=pd.read_csv(url)

file_id="1opH7S0T-rCvV9kutETP4D0bi81Qcp5RF"
url=f"https://drive.google.com/uc?id={file_id}"
df1_23=pd.read_csv(url)

# %%
concatenated_df = pd.concat([df1_24, df2_24], axis=0, ignore_index=True)
for i in range(3,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_24"]], axis=0, ignore_index=True)
    concatenated_df=df
for i in range(1,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_23"]], axis=0, ignore_index=True)
    concatenated_df=df
    
df['regular_datetime']=pd.to_datetime(df['regular_datetime'])
df=df.sort_values(by='regular_datetime')
pd.DataFrame(df)
# Out:
#         Unnamed: 0          regular_datetime  accruedToTreasury  \
# 277128         336 2023-01-27 08:00:00+00:00       1.055897e-07
# 277464         672 2023-01-27 08:00:00+00:00                NaN
# 277016         224 2023-01-27 08:00:00+00:00       0.000000e+00
# 277240         448 2023-01-27 08:00:00+00:00                NaN
# 276792           0 2023-01-27 08:00:00+00:00       0.000000e+00
# ...            ...                       ...                ...
# 263399       12647 2024-12-31 23:00:00+00:00       2.044270e-02
# 255215        4463 2024-12-31 23:00:00+00:00       8.947297e+02
# 253727        2975 2024-12-31 23:00:00+00:00       1.593248e+04
# 255959        5207 2024-12-31 23:00:00+00:00       2.110239e+00
# 273071       22319 2024-12-31 23:00:00+00:00       0.000000e+00
#
#         availableLiquidity  averageStableBorrowRate  liquidityIndex  \
# 277128        3.001000e+00                      0.0        1.000014
# ...

# %%
df.to_pickle("reserve_features.pkl")  # Sauvegarde rapide

# %%
file_id="1kQ9Jg_I1NW0YIiEI0gXTiSeYaes-NLqO"
url=f"https://drive.google.com/uc?id={file_id}"
df12_24=pd.read_csv(url)



file_id="1Rus62iSPF5BLXewy5OVIIpuEESG2btvT"
url=f"https://drive.google.com/uc?id={file_id}"
df11_24=pd.read_csv(url)


file_id="1H_GDlRKYcWouz8saO7u3rtJrhtoTK-GA"
url=f"https://drive.google.com/uc?id={file_id}"
df10_24=pd.read_csv(url)


file_id="1OPpb-gMmahUh-5TViUnKx8tdHyW1KrHJ"
url=f"https://drive.google.com/uc?id={file_id}"
df9_24=pd.read_csv(url)


file_id="1T7WZK1eIHVTVldn72PnFtob_yLJj3rYb"
url=f"https://drive.google.com/uc?id={file_id}"
df8_24=pd.read_csv(url)


file_id="1fJ_6h4TMMh8D8DTgMTE1Y-UFBPQRobCN"
url=f"https://drive.google.com/uc?id={file_id}"
df7_24=pd.read_csv(url)


file_id="15dc6oZ9Xu7RJvqxWN-T8NXA4_qVyYg29"
url=f"https://drive.google.com/uc?id={file_id}"
df6_24=pd.read_csv(url)


file_id="18rA4K3ZHEUiQS-369vJ5QJ8BB9pVnR-I"
url=f"https://drive.google.com/uc?id={file_id}"
df5_24=pd.read_csv(url)


file_id="1T0UBaWBWGfGqgdvlanOQ9au4sKajrHrQ"
url=f"https://drive.google.com/uc?id={file_id}"
df4_24=pd.read_csv(url)


file_id="11YoRnXIC_dWhCOrWdwlw43rZlWwzniMD"
url=f"https://drive.google.com/uc?id={file_id}"
df3_24=pd.read_csv(url)


file_id="1cXHWTtBSZXbjdtQsxlQkuNGL5mn4MDt_"
url=f"https://drive.google.com/uc?id={file_id}"
df2_24=pd.read_csv(url)


file_id="194ddXWTBn8kF4BvGYaBNIKJip9RB6O16"
url=f"https://drive.google.com/uc?id={file_id}"
df1_24=pd.read_csv(url)


file_id="1bo_o3YoXfGERvX-ajVTTR6DfECC6tJq9"
url=f"https://drive.google.com/uc?id={file_id}"
df12_23=pd.read_csv(url)


file_id="1q07kk_AmxC0K2wcDD7k0GbSUUirVAW75"
url=f"https://drive.google.com/uc?id={file_id}"
df11_23=pd.read_csv(url)


file_id="1NfayRWKTZpC2fUphMf-xNQLJyt0HaIQ6"
url=f"https://drive.google.com/uc?id={file_id}"
df10_23=pd.read_csv(url)


file_id="11TAiz0Wwyda0iHoZcoEeXR1IasqSF5gk"
url=f"https://drive.google.com/uc?id={file_id}"
df9_23=pd.read_csv(url)


ValueError
file_id="1rsaRjv20Lr4zwP7XrwYGulQi2pcEr_m0"
url=f"https://drive.google.com/uc?id={file_id}"
df8_23=pd.read_csv(url)


file_id="1-fAK4LrJI-WqIwNM5q_8zoEkHYXjGbxX"
url=f"https://drive.google.com/uc?id={file_id}"
df7_23=pd.read_csv(url)


file_id="1f4GGiUcKlp7o_gwsnC6eg_IMox5J1bzH"
url=f"https://drive.google.com/uc?id={file_id}"
df6_23=pd.read_csv(url)


file_id="1kjh5ks1-C2GL58nnQE7ZYmxyGXZAP1sa"
url=f"https://drive.google.com/uc?id={file_id}"
df5_23=pd.read_csv(url)


file_id="1ApUr_Ev1se0wetSlwNeIVrGqUJVCKDh4"
url=f"https://drive.google.com/uc?id={file_id}"
df4_23=pd.read_csv(url)


file_id="1F8j1ShI4PaLZnQBtKzNIB7j9jIbiy6Rl"
url=f"https://drive.google.com/uc?id={file_id}"
df3_23=pd.read_csv(url)


file_id="1oUMe-PJsPYbpLiNAwRY99aJmWph1ZtfO"
url=f"https://drive.google.com/uc?id={file_id}"
df2_23=pd.read_csv(url)


file_id="1pGXrJLXCWwcZLJnKTlQfRD2NNHQG0cUV"
url=f"https://drive.google.com/uc?id={file_id}"
df1_23=pd.read_csv(url)



concatenated_df = pd.concat([df1_24, df2_24], axis=0, ignore_index=True)
for i in range(3,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_24"]], axis=0, ignore_index=True)
    concatenated_df=df
for i in range(1,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_23"]], axis=0, ignore_index=True)
    concatenated_df=df
    
df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')
df=df.sort_values(by='datetime')
pd.DataFrame(df)
# Out:
#         Unnamed: 0  action       amount  assetPriceUSD  \
# 159792         354  Borrow     1.000000       1.000158
# 159791         353  Borrow     0.041100    1585.870000
# 159790         352  Borrow   105.000000       0.999954
# 159789         351  Borrow     0.500000    1581.138800
# 159788         350  Borrow   300.000000       0.999954
# ...            ...     ...          ...            ...
# 138125           4  Borrow     1.000000    1782.440000
# 138124           3  Borrow  1000.000000       1.000212
# 138123           2  Borrow  3600.000000       1.000212
# 138122           1  Borrow     5.262933       0.000000
# 138121           0  Borrow     1.000000    1782.440000
#
#                                                        id   timestamp  \
# 159792  16496939:64:0xa7b2a6f0161a0f7003261a8a05bcea5c...  1674807887
# 159791  16497032:89:0x80ec455347ce252df8eea5cdd0c41543...  1674809003
# 159790  16497271:75:0x181745eebed8c98b6430a3b3a8ff461d...  1674811895
# ...

# %%
df.to_pickle("borrow.pkl")

# %%
file_id="1JiCgKXYycRQUhAQ-SjymIBI5a3qfeCKD"
url=f"https://drive.google.com/uc?id={file_id}"
df12_24=pd.read_csv(url)



file_id="1bDH47HR6quOi-69m2FBaRK8Bic2L71sL"
url=f"https://drive.google.com/uc?id={file_id}"
df11_24=pd.read_csv(url)


file_id="1O66U42PzRI3szqdA2IVosjHeRjxR3z1Z"
url=f"https://drive.google.com/uc?id={file_id}"
df10_24=pd.read_csv(url)


file_id="14MbrXZEL4b_JXPuJXrgwe_fdNuZnNLWM"
url=f"https://drive.google.com/uc?id={file_id}"
df9_24=pd.read_csv(url)


file_id="1fFv5b_LCXsr714eSFZPW0LJIUbGTijXj"
url=f"https://drive.google.com/uc?id={file_id}"
df8_24=pd.read_csv(url)


file_id="1IPdKHEl-JFsCey15utAu6mMRWXI65Zad"
url=f"https://drive.google.com/uc?id={file_id}"
df7_24=pd.read_csv(url)


file_id="1XBHnUfuCZZNYQ62g-pLBVTXR1Ngtzyv-"
url=f"https://drive.google.com/uc?id={file_id}"
df6_24=pd.read_csv(url)


file_id="1qlmsRTvJ16mxnYMVrcPL1O-Z3_EZyZJt"
url=f"https://drive.google.com/uc?id={file_id}"
df5_24=pd.read_csv(url)


file_id="1B590dpoTNPtk2JZA8Ktr2QlZOILPp0i3"
url=f"https://drive.google.com/uc?id={file_id}"
df4_24=pd.read_csv(url)


file_id="1xXcJLvpjlQMj8xve91Oaa1Qz7jAiNoft"
url=f"https://drive.google.com/uc?id={file_id}"
df3_24=pd.read_csv(url)


file_id="16MwnbNlEWMJEphUWPyEDSTWTkNUv0WAt"
url=f"https://drive.google.com/uc?id={file_id}"
df2_24=pd.read_csv(url)


file_id="1NvfAQc-1iFeLo38wui2k20JnMZfGY1kO"
url=f"https://drive.google.com/uc?id={file_id}"
df1_24=pd.read_csv(url)


file_id="1nHloKzFwll47Z1AO_YttLjLWAkQ7_Di8"
url=f"https://drive.google.com/uc?id={file_id}"
df12_23=pd.read_csv(url)


file_id="1wJc-oBLkJUt9AYptCwfOm2Zkdv3IAdW0"
url=f"https://drive.google.com/uc?id={file_id}"
df11_23=pd.read_csv(url)


file_id="1fuJ2XOmz9oDS8Q-OGY34RPMGuGkh4Dyi"
url=f"https://drive.google.com/uc?id={file_id}"
df10_23=pd.read_csv(url)


file_id="1Kk7UmK-iyuzUaQr56TrMddqMsmI9qpFg"
url=f"https://drive.google.com/uc?id={file_id}"
df9_23=pd.read_csv(url)


ValueError
file_id="1nSHEjgZpcOBVQdXahXd0wyBvE5WHZg3X"
url=f"https://drive.google.com/uc?id={file_id}"
df8_23=pd.read_csv(url)


file_id="18bTKpWf3sR7yuEr5_8lpe50BuNXIlu-4"
url=f"https://drive.google.com/uc?id={file_id}"
df7_23=pd.read_csv(url)


file_id="1hC7CT6457tWfYz8c0C1A4hqX_sxfkZq-"
url=f"https://drive.google.com/uc?id={file_id}"
df6_23=pd.read_csv(url)


file_id="1Ks-MUkxEoMZcmeoswfGOZ4SVjf_YsAji"
url=f"https://drive.google.com/uc?id={file_id}"
df5_23=pd.read_csv(url)


file_id="1gjMU5wzS8-qENydVq3klu7A9Nrxu0xyy"
url=f"https://drive.google.com/uc?id={file_id}"
df4_23=pd.read_csv(url)


file_id="1_ipUYAjmHs6GE1BXdlT9MpOhpgb-Bxe2"
url=f"https://drive.google.com/uc?id={file_id}"
df3_23=pd.read_csv(url)


file_id="1wz757yFA2VkP74ceQAs54kxbUtotKEMF"
url=f"https://drive.google.com/uc?id={file_id}"
df2_23=pd.read_csv(url)


file_id="1NacksbBajA3JRovWJFIoNqYUANs5SdMt"
url=f"https://drive.google.com/uc?id={file_id}"
df1_23=pd.read_csv(url)



concatenated_df = pd.concat([df1_24, df2_24], axis=0, ignore_index=True)
for i in range(3,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_24"]], axis=0, ignore_index=True)
    concatenated_df=df
for i in range(1,13):
    df = pd.concat([concatenated_df, globals()[f"df{i}_23"]], axis=0, ignore_index=True)
    concatenated_df=df
    
df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')
df=df.sort_values(by='datetime')
pd.DataFrame(df)
# Out:
#         Unnamed: 0  action       amount  assetPriceUSD  \
# 224776         807  Supply     0.040000    1585.166200
# 224775         806  Supply     0.001000    1585.870000
# 224774         805  Supply     1.584767       1.000158
# 224773         804  Supply     0.001000    1585.870000
# 224772         803  Supply     0.000100    1585.870000
# ...            ...     ...          ...            ...
# 193122           4  Supply     0.300000    1782.440000
# 193121           3  Supply     7.390727    1782.440000
# 193120           2  Supply     0.090000    1782.440000
# 193119           1  Supply  4014.000000       1.000212
# 193118           0  Supply   550.000000    1782.440000
#
#                                                        id   timestamp  \
# 224776  16496817:398:0xa4a5f3993fd60bd01665f8389c1c5cd...  1674806411
# 224775  16496920:155:0x55dad875c908b12f0e2c0ce3e102951...  1674807647
# 224774  16496928:62:0x4a88a8c6a43b5df2ee59ebcf266225fb...  1674807743
# ...

# %%
df.to_pickle("deposit.pkl")

# %%
import pandas as pd
import os

# %%
dfs = []

for year in [2024, 2023]:
    for month in range(1, 13):
        filename = f"events_data_liquidationCall_{year}-{month}.csv"
        filepath = os.path.join(base_path, filename)
        df = pd.read_csv(filepath)
        dfs.append(df)

merged_df = pd.concat(dfs, axis=0, ignore_index=True)

merged_df['datetime'] = pd.to_datetime(merged_df['timestamp'], unit='s')
merged_df = merged_df.sort_values(by='datetime')
merged_df.to_pickle("liquidationCall.pkl")

# %%
dfs = []

for year in [2024, 2023]:
    for month in range(1, 13):
        filename = f"events_data_redeemUnderlying_{year}-{month}.csv"
        filepath = os.path.join(base_path, filename)
        df = pd.read_csv(filepath)
        dfs.append(df)

merged_df = pd.concat(dfs, axis=0, ignore_index=True)

merged_df['datetime'] = pd.to_datetime(merged_df['timestamp'], unit='s')
merged_df = merged_df.sort_values(by='datetime')
merged_df.to_pickle("redeemUnderlying.pkl")

# %%
dfs = []

for year in [2024, 2023]:
    for month in range(1, 13):
        filename = f"events_data_repay_{year}-{month}.csv"
        filepath = os.path.join(base_path, filename)
        df = pd.read_csv(filepath)
        dfs.append(df)

merged_df = pd.concat(dfs, axis=0, ignore_index=True)

merged_df['datetime'] = pd.to_datetime(merged_df['timestamp'], unit='s')
merged_df = merged_df.sort_values(by='datetime')
merged_df.to_pickle("repay.pkl")
